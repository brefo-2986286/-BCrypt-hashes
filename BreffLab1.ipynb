# %% [markdown]
# <a href="https://colab.research.google.com/github/brefo-2986286/-BCrypt-hashes/blob/main/BreffLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Getting data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf

# %%
df= yf.download("AAPL",
                start="2013-01-01",
                end="2023-12-31",
                progress=False)

# %%
print(f"Donwloaded {len(df)} rows of data. ")
df
# Out:
# Donwloaded 2768 rows of data.
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-01-02   19.779285   19.821428   19.343929   19.608213   16.769091
# 2013-01-03   19.567142   19.631071   19.321428   19.360714   16.557430
# 2013-01-04   19.177500   19.236786   18.779642   18.821428   16.096228
# 2013-01-07   18.642857   18.903570   18.400000   18.710714   16.001543
# 2013-01-08   18.900356   18.996071   18.616072   18.761070   16.044611
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.600006
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  193.050003
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  193.149994
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.580002
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.529999
#
#                Volume
# Date
# 2013-01-02  560518000
# 2013-01-03  352965200
# 2013-01-04  594333600
# 2013-01-07  484156400
# 2013-01-08  458707200
# ...               ...
# 2023-12-22   37122800
# 2023-12-26   28919300
# 2023-12-27   48087700
# 2023-12-28   34049900
# 2023-12-29   42628800
#
# [2768 rows x 6 columns]

# %%
aapl_data=yf.Ticker("AAPL")

# %%
aapl_data.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-12-11 00:00:00-05:00  193.110001  193.490005  191.419998  193.179993
# 2023-12-12 00:00:00-05:00  193.080002  194.720001  191.720001  194.710007
# 2023-12-13 00:00:00-05:00  195.089996  198.000000  194.850006  197.960007
# 2023-12-14 00:00:00-05:00  198.020004  199.619995  196.160004  198.110001
# 2023-12-15 00:00:00-05:00  197.529999  198.399994  197.000000  197.570007
# 2023-12-18 00:00:00-05:00  196.089996  196.630005  194.389999  195.889999
# 2023-12-19 00:00:00-05:00  196.160004  196.949997  195.889999  196.940002
# 2023-12-20 00:00:00-05:00  196.899994  197.679993  194.830002  194.830002
# 2023-12-21 00:00:00-05:00  196.100006  197.080002  193.500000  194.679993
# 2023-12-22 00:00:00-05:00  195.179993  195.410004  192.970001  193.600006
# 2023-12-26 00:00:00-05:00  193.610001  193.889999  192.830002  193.050003
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# 2023-12-28 00:00:00-05:00  194.139999  194.660004  193.169998  193.580002
# 2023-12-29 00:00:00-05:00  193.899994  194.399994  191.729996  192.529999
# 2024-01-02 00:00:00-05:00  187.149994  188.440002  183.889999  185.639999
# 2024-01-03 00:00:00-05:00  184.220001  185.880005  183.429993  184.250000
# 2024-01-04 00:00:00-05:00  182.149994  183.089996  180.880005  181.910004
# 2024-01-05 00:00:00-05:00  181.990005  182.759995  180.169998  181.179993
# 2024-01-08 00:00:00-05:00  182.089996  185.600006  181.500000  185.559998
# 2024-01-09 00:00:00-05:00  183.919998  185.149994  182.729996  185.139999
# 2024-01-10 00:00:00-05:00  184.350006  186.399994  183.919998  186.190002
# 2024-01-11 00:00:00-05:00  186.539993  187.050003  183.619995  184.166595
#
#                               Volume  Dividends  Stock Splits
# Date
# 2023-12-11 00:00:00-05:00   60943700        0.0           0.0
# 2023-12-12 00:00:00-05:00   52696900        0.0           0.0
# 2023-12-13 00:00:00-05:00   70404200        0.0           0.0
# 2023-12-14 00:00:00-05:00   66831600        0.0           0.0
# 2023-12-15 00:00:00-05:00  128256700        0.0           0.0
# 2023-12-18 00:00:00-05:00   55751900        0.0           0.0
# 2023-12-19 00:00:00-05:00   40714100        0.0           0.0
# 2023-12-20 00:00:00-05:00   52242800        0.0           0.0
# 2023-12-21 00:00:00-05:00   46482500        0.0           0.0
# 2023-12-22 00:00:00-05:00   37122800        0.0           0.0
# 2023-12-26 00:00:00-05:00   28919300        0.0           0.0
# 2023-12-27 00:00:00-05:00   48087700        0.0           0.0
# 2023-12-28 00:00:00-05:00   34049900        0.0           0.0
# 2023-12-29 00:00:00-05:00   42628800        0.0           0.0
# 2024-01-02 00:00:00-05:00   82488700        0.0           0.0
# 2024-01-03 00:00:00-05:00   58414500        0.0           0.0
# 2024-01-04 00:00:00-05:00   71983600        0.0           0.0
# 2024-01-05 00:00:00-05:00   62303300        0.0           0.0
# 2024-01-08 00:00:00-05:00   59144500        0.0           0.0
# 2024-01-09 00:00:00-05:00   42841800        0.0           0.0
# 2024-01-10 00:00:00-05:00   46730900        0.0           0.0
# 2024-01-11 00:00:00-05:00   21689165        0.0           0.0

# %% [markdown]
# Getting data from Nasdaq Data Link

# %%
import pandas as pd
import nasdaqdatalink

# %%
nasdaqdatalink.ApiConfig.api_key = "N_bYJhD_dxUA9x--j8y5"

# %%
dfnas = nasdaqdatalink.get(dataset='WIKI/AAPL',
                        start_date='2013-01-01',
                        end_date='2023-12-31')

# %%
print(f'Donwloanded {len(dfnas)} rows of data. ')
dfnas.head()
# Out:
# Donwloanded 3949 rows of data.
#      ticker       date  adj_close
# None
# 0      MSFT 2018-03-27      89.47
# 1      MSFT 2018-03-26      93.78
# 2      MSFT 2018-03-23      87.18
# 3      MSFT 2018-03-22      89.79
# 4      MSFT 2018-03-21      92.48

# %% [markdown]
# Download the data for multiple tickers

# %%
COLUMNS = ["ticker", "date", "adj_close"]
dfnas = nasdaqdatalink.get_table("WIKI/PRICES",
                              ticker=["AAPL", "MSFT", "INTC"],
                              qopts={"columns": COLUMNS},
                              date= {"gte": "2013-01-01",
                                    "lte": "2023-12-31"},
                              paginate=True)
dfnas.head()
# Out:
#      ticker       date  adj_close
# None
# 0      MSFT 2018-03-27      89.47
# 1      MSFT 2018-03-26      93.78
# 2      MSFT 2018-03-23      87.18
# 3      MSFT 2018-03-22      89.79
# 4      MSFT 2018-03-21      92.48

# %%
from __future__ import print_function
import time
import intrinio_sdk as intrinio
from intrinio_sdk.rest import ApiException

# %%
intrinio.ApiClient().set_api_key("OmY3Yzc3ZDNiNjU2MmJkN2I0ZDEwMWU3NzVjMTc5M2Yx")
intrinio.ApiClient().allow_retries(True)

# %% [markdown]
# # New Section

# %% [markdown]
# Getting data from Alpha Vantage

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
ALPHA_VANTAGE_API_KEY = "VNNLJ0E08M8UVYOY"
crypto_api = CryptoCurrencies(key=ALPHA_VANTAGE_API_KEY,
                              output_format= "pandas")

# %%
data, meta_data = crypto_api.get_digital_currency_daily(
    symbol="BTC",
    market="EUR"
)

# %%
meta_data
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#  '2. Digital Currency Code': 'BTC',
#  '3. Digital Currency Name': 'Bitcoin',
#  '4. Market Code': 'EUR',
#  '5. Market Name': 'Euro',
#  '6. Last Refreshed': '2024-01-11 00:00:00',
#  '7. Time Zone': 'UTC'}

# %%
data
# Out:
#             1a. open (EUR)  1b. open (USD)  2a. high (EUR)  2b. high (USD)  \
# date
# 2024-01-11    42492.463200        46654.00    42579.900000        46750.00
# 2024-01-10    41996.988000        46110.00    43441.453044        47695.93
# 2024-01-09    42763.007232        46951.04    43692.897600        47972.00
# 2024-01-08    40010.542308        43929.01    43034.380092        47248.99
# 2024-01-07    40046.345856        43968.32    40512.921372        44480.59
# ...                    ...             ...             ...             ...
# 2021-04-21    51391.890000        56425.00    51695.104428        56757.91
# 2021-04-20    50670.663912        55633.14    51985.039392        57076.24
# 2021-04-19    51141.429108        56150.01    52395.418548        57526.81
# 2021-04-18    54654.075036        60006.67    55102.489200        60499.00
# 2021-04-17    55863.744948        61334.81    56930.510340        62506.05
#
#             3a. low (EUR)  3b. low (USD)  4a. close (EUR)  4b. close (USD)  \
# date
# 2024-01-11   42166.815768       46296.46     42371.417880         46521.10
# 2024-01-10   40348.767888       44300.36     42492.454092         46653.99
# 2024-01-09   40757.088636       44748.67     41996.988000         46110.00
# 2024-01-08   39323.790000       43175.00     42763.007232         46951.04
# 2024-01-07   39685.459572       43572.09     40010.551416         43929.02
# ...                   ...            ...              ...              ...
# 2021-04-21   48760.607016       53536.02     48989.773404         53787.63
# 2021-04-20   48572.927568       53329.96     51391.890000         56425.00
# 2021-04-19   49385.015064       54221.58     50670.663912         55633.14
# 2021-04-18   46388.228040       50931.30     51141.429108         56150.01
# 2021-04-17   54266.292828       59580.91     54654.065928         60006.66
#
#                 5. volume  6. market cap (USD)
# date
# 2024-01-11    4640.256430          4640.256430
# 2024-01-10   89911.412030         89911.412030
# 2024-01-09   69927.666170         69927.666170
# 2024-01-08   72814.575890         72814.575890
# 2024-01-07   23023.850800         23023.850800
# ...                   ...                  ...
# 2021-04-21   66984.756909         66984.756909
# 2021-04-20   72744.482151         72744.482151
# 2021-04-19   78229.042267         78229.042267
# 2021-04-18  124882.131824        124882.131824
# 2021-04-17   58912.256128         58912.256128
#
# [1000 rows x 10 columns]

# %% [markdown]
# DataFrame with the current exchange rate:

# %%
crypto_api.get_digital_currency_exchange_rate(
    from_currency="BTC",
    to_currency="USD"
)[0].transpose()
# Out:
#                       Realtime Currency Exchange Rate
# 1. From_Currency Code                             BTC
# 2. From_Currency Name                         Bitcoin
# 3. To_Currency Code                               USD
# 4. To_Currency Name              United States Dollar
# 5. Exchange Rate                       46514.55000000
# 6. Last Refreshed                 2024-01-11 18:45:03
# 7. Time Zone                                      UTC
# 8. Bid Price                           46514.54000000
# 9. Ask Price                           46514.55000000

# %%
import requests
import pandas as pd
from io import BytesIO

# %% [markdown]
# Download the upcoming earnings announcements within the next three months:

# %%
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "EARNINGS_CALENDAR",
    "horizon": "3month",
    "apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL, params=parameters)
pd.read_csv(BytesIO(r.content))
# Out:
#      symbol                             name  reportDate fiscalDateEnding  \
# 0         A         Agilent Technologies Inc  2024-02-26       2024-01-31
# 1        AA                       Alcoa Corp  2024-01-16       2023-12-31
# 2     AACAY                            AACAY  2024-03-21       2023-12-31
# 3      AACG            ATA Creativity Global  2024-03-28       2023-12-31
# 4     AACTF                            AACTF  2024-02-28       2023-12-31
# ...     ...                              ...         ...              ...
# 7565   ZVOI                             ZVOI  2024-02-28       2023-12-31
# 7566   ZVRA           Zevra Therapeutics Inc  2024-03-05       2023-12-31
# 7567    ZWS  Zurn Elkay Water Solutions Corp  2024-02-05       2023-12-31
# 7568   ZYNE                             ZYNE  2024-03-26       2023-12-31
# 7569   ZYXI                        Zynex Inc  2024-03-04       2023-12-31
#
#       estimate currency
# 0       1.2200      USD
# 1      -0.8100      USD
# 2       0.0373      CNY
# 3          NaN      CNY
# 4          NaN      USD
# ...        ...      ...
# 7565    0.0000      USD
# 7566   -0.2800      USD
# 7567    0.2300      USD
# 7568       NaN      USD
# 7569    0.1700      USD
#
# [7570 rows x 6 columns]

# %% [markdown]
# Getting data from CoinGecko

# %%
# !pip install pyCoinGecko
# Out:
# Collecting pyCoinGecko
#   Downloading pycoingecko-3.1.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pyCoinGecko) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pyCoinGecko) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pyCoinGecko) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pyCoinGecko) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pyCoinGecko) (2023.11.17)
# Installing collected packages: pyCoinGecko
# Successfully installed pyCoinGecko-3.1.0

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import pandas as pd

# %%
cg = CoinGeckoAPI()

# %% [markdown]
# Get Bitcoin’s OHLC prices from the last 14 days

# %%
ohlc = cg.get_coin_ohlc_by_id(
    id="bitcoin", vs_currency="usd", days="14"
)
ohlc_df = pd.DataFrame(ohlc)
ohlc_df.columns = ["date", "open", "high", "low", "close"]
ohlc_df["date"] = pd.to_datetime(ohlc_df["date"], unit="ms")
ohlc_df
# Out:
#                   date     open     high      low    close
# 0  2023-12-29 00:00:00  42632.0  42632.0  42442.0  42619.0
# 1  2023-12-29 04:00:00  42601.0  42623.0  42343.0  42623.0
# 2  2023-12-29 08:00:00  42761.0  42761.0  42564.0  42564.0
# 3  2023-12-29 12:00:00  42328.0  42742.0  42328.0  42742.0
# 4  2023-12-29 16:00:00  42880.0  42983.0  42835.0  42983.0
# ..                 ...      ...      ...      ...      ...
# 79 2024-01-11 04:00:00  46632.0  46726.0  46520.0  46617.0
# 80 2024-01-11 08:00:00  46469.0  46469.0  45883.0  45883.0
# 81 2024-01-11 12:00:00  46103.0  46865.0  46103.0  46865.0
# 82 2024-01-11 16:00:00  47100.0  48495.0  47100.0  48495.0
# 83 2024-01-11 20:00:00  46727.0  46727.0  45963.0  46549.0
#
# [84 rows x 5 columns]

# %% [markdown]
# Get the top 7 trending coins

# %%
trending_coins = cg.get_search_trending()
(
    pd.DataFrame([coin["item"] for coin in trending_coins["coins"]])
    .drop(columns=["thumb", "small", "large"])
)
# Out:
#                 id  coin_id          name symbol  market_cap_rank  \
# 0       memecoin-2    32528      Memecoin   MEME              213
# 1           tectum    29575        Tectum    TET              195
# 2       dogwifcoin    33566     dogwifhat    WIF              205
# 3     paid-network    13761  PAID Network   PAID              446
# 4   xai-blockchain    34258           Xai    XAI              257
# 5         celestia    31967      Celestia    TIA               41
# 6              sui    26375           Sui    SUI               66
# 7          inspect    33422       Inspect   INSP              655
# 8      sei-network    28205           Sei    SEI               51
# 9          coq-inu    33511       Coq Inu    COQ              362
# 10        arbitrum    16547      Arbitrum    ARB               37
# 11          solana     4128        Solana    SOL                5
# 12            bonk    28600          Bonk   BONK               73
# 13        ethereum      279      Ethereum    ETH                2
# 14        optimism    25244      Optimism     OP               28
#
#             slug     price_btc  score  \
# 0           meme  5.767203e-07      0
# 1         tectum  8.250015e-04      1
# 2      dogwifhat  5.516377e-06      2
# 3   paid-network  7.265937e-06      3
# 4            xai  1.355470e-05      4
# 5       celestia  3.506965e-04      5
# 6            sui  2.323401e-05      6
# 7        inspect  5.063310e-06      7
# 8            sei  1.597704e-05      8
# 9        coq-inu  3.266082e-11      9
# 10      arbitrum  4.760433e-05     10
# 11        solana  2.158906e-03     11
# 12          bonk  3.508642e-10     12
# 13      ethereum  5.614015e-02     13
# 14      optimism  8.284117e-05     14
#
#                                                  data
# 0   {'price': '$0.026828535697', 'price_btc': '0.0...
# 1   {'price': '$38.38', 'price_btc': '0.0008250015...
# 2   {'price': '$0.256617', 'price_btc': '0.0000055...
# 3   {'price': '$0.338005', 'price_btc': '0.0000072...
# 4   {'price': '$0.630470', 'price_btc': '0.0000135...
# 5   {'price': '$16.31', 'price_btc': '0.0003506965...
# 6   {'price': '$1.08', 'price_btc': '0.00002323400...
# 7   {'price': '$0.235541', 'price_btc': '0.0000050...
# 8   {'price': '$0.743238', 'price_btc': '0.0000159...
# 9   {'price': '$0.000001519354', 'price_btc': '0.0...
# 10  {'price': '$2.21', 'price_btc': '0.00004760433...
# 11  {'price': '$100.43', 'price_btc': '0.002158906...
# 12  {'price': '$0.000016321905', 'price_btc': '0.0...
# 13  {'price': '$2,611.59', 'price_btc': '0.0561401...
# 14  {'price': '$3.85', 'price_btc': '0.00008284116...

# %% [markdown]
# Get Bitcoin’s current price in USD

# %%
cg.get_price(ids="bitcoin", vs_currencies="usd")
# Out:
# {'bitcoin': {'usd': 46455}}

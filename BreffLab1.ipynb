# %% [markdown]
# <a href="https://colab.research.google.com/github/brefo-2986286/-BCrypt-hashes/blob/main/BreffLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf

# %%
df= yf.download("AAPL",
                start="2011-01-01",
                end="2021-12-31",
                progress=False)

# %%
print(f"Donwloaded {len(df)} rows of data. ")
df
# Out:
# Donwloaded 2768 rows of data.
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-03   11.630000   11.795000   11.601429   11.770357    9.977493
# 2011-01-04   11.872857   11.875000   11.719643   11.831786   10.029567
# 2011-01-05   11.769643   11.940714   11.767857   11.928571   10.111607
# 2011-01-06   11.954286   11.973214   11.889286   11.918929   10.103437
# 2011-01-07   11.928214   12.012500   11.853571   12.004286   10.175790
# ...                ...         ...         ...         ...         ...
# 2021-12-23  175.850006  176.850006  175.270004  176.279999  174.288620
# 2021-12-27  177.089996  180.419998  177.070007  180.330002  178.292877
# 2021-12-28  180.160004  181.330002  178.529999  179.289993  177.264633
# 2021-12-29  179.330002  180.630005  178.139999  179.380005  177.353607
# 2021-12-30  179.470001  180.570007  178.089996  178.199997  176.186935
#
#                Volume
# Date
# 2011-01-03  445138400
# 2011-01-04  309080800
# ...

# %%
aapl_data=yf.Ticker("AAPL")

# %%
aapl_data.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-12-11 00:00:00-05:00  193.110001  193.490005  191.419998  193.179993
# 2023-12-12 00:00:00-05:00  193.080002  194.720001  191.720001  194.710007
# 2023-12-13 00:00:00-05:00  195.089996  198.000000  194.850006  197.960007
# 2023-12-14 00:00:00-05:00  198.020004  199.619995  196.160004  198.110001
# 2023-12-15 00:00:00-05:00  197.529999  198.399994  197.000000  197.570007
# 2023-12-18 00:00:00-05:00  196.089996  196.630005  194.389999  195.889999
# 2023-12-19 00:00:00-05:00  196.160004  196.949997  195.889999  196.940002
# 2023-12-20 00:00:00-05:00  196.899994  197.679993  194.830002  194.830002
# 2023-12-21 00:00:00-05:00  196.100006  197.080002  193.500000  194.679993
# 2023-12-22 00:00:00-05:00  195.179993  195.410004  192.970001  193.600006
# 2023-12-26 00:00:00-05:00  193.610001  193.889999  192.830002  193.050003
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# ...

# %%
import pandas as pd
import nasdaqdatalink

# %%
nasdaqdatalink.ApiConfig.api_key = "N_bYJhD_dxUA9x--j8y5"

# %%
df = nasdaqdatalink.get(dataset='WIKI/AAPL',
                        start_date='2011-01-01',
                        end_date='2021-12-31')

# %%
print(f'Donwloanded {len(df)} rows of data. ')
df.head()
# Out:
# Donwloanded 1818 rows of data.
#                 Open    High       Low   Close      Volume  Ex-Dividend  \
# Date
# 2011-01-03  325.6400  330.26  324.8365  329.57  15897800.0          0.0
# 2011-01-04  332.4400  332.50  328.1500  331.29  11038600.0          0.0
# 2011-01-05  329.5500  334.34  329.5000  334.00   9125700.0          0.0
# 2011-01-06  334.7194  335.25  332.9000  333.73  10729600.0          0.0
# 2011-01-07  333.9900  336.35  331.9000  336.12  11140400.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2011-01-03          1.0  41.849279  42.443013  41.746018   42.354338
# 2011-01-04          1.0  42.723173  42.730884  42.171849   42.575382
# 2011-01-05          1.0  42.351768  42.967350  42.345342   42.923655
# 2011-01-06          1.0  43.016108  43.084298  42.782290   42.888956
# 2011-01-07          1.0  42.922370  43.225663  42.653776   43.196105
#
#             Adj. Volume
# Date
# 2011-01-03  111284600.0
# ...

# %%
COLUMNS = ["ticker", "date", "adj_close"]
df = nasdaqdatalink.get_table("WIKI/PRICES",
                              ticker=["AAPL", "MSFT", "INTC"],
                              qopts={"columns": COLUMNS},
                              date={"gte": "2011-01-01",
                                    "lte": "2021-12-31"},
                              paginate=True)
df.head()
# Out:
#      ticker       date  adj_close
# None
# 0      MSFT 2018-03-27      89.47
# 1      MSFT 2018-03-26      93.78
# 2      MSFT 2018-03-23      87.18
# 3      MSFT 2018-03-22      89.79
# 4      MSFT 2018-03-21      92.48

# %%
df = df.set_index ("date")
df_wide = df.pivot(colums='ticker')
df_wide.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-86e6a65d2f43> in <cell line: 1>()
# ----> 1 df = df.set_index ("date")
#       2 df_wide = df.pivot(colums='ticker')
#       3 df_wide.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
# !pip install intrinio_sdk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.1 MB/s eta 0:00:00
# ...

# %%
import intrinio_sdk as intrinio
import pandas as pd

# %%
intrinio.ApiClient().set_api_key("OmY3Yzc3ZDNiNjU2MmJkN2I0ZDEwMWU3NzVjMTc5M2Yx")
security_api = intrinio.SecurityApi()

# %%
r = security_api.get_security_stock_prices(
    identifier="AAPL",
    start_date="2011-01-01",
    end_date="2021-12-31",
    frequency="daily",
    page_size=10000
)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-57-910dcb38ff1d> in <cell line: 1>()
# ----> 1 r = security_api.get_security_stock_prices(
#       2     identifier="AAPL",
#       3     start_date="2011-01-01",
#       4     end_date="2021-12-31",
#       5     frequency="daily",
#
# /usr/local/lib/python3.10/dist-packages/intrinio_sdk/api/security_api.py in get_security_stock_prices(self, identifier, **kwargs)
#    5870             return self.get_security_stock_prices_with_http_info(identifier, **kwargs)  # noqa: E501
#    5871         else:
# -> 5872             (data) = self.get_security_stock_prices_with_http_info(identifier, **kwargs)  # noqa: E501
#    5873             return data
#    5874
#
# /usr/local/lib/python3.10/dist-packages/intrinio_sdk/api/security_api.py in get_security_stock_prices_with_http_info(self, identifier, **kwargs)
# ...

# %%
df = (
    pd.DataFrame(r.stock_prices_dict)
    .sort_values("date")
    .set_index("date")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-adc85bdcacac> in <cell line: 2>()
#       1 df = (
# ----> 2     pd.DataFrame(r.stock_prices_dict)
#       3     .sort_values("date")
#       4     .set_index("date")
#       5 )
#
# NameError: name 'r' is not defined

# %%
print(f"Downloaded {df.shape[0]} rows of data.")
df.head()
# Out:
# Downloaded 5455 rows of data.
# Empty DataFrame
# Columns: []
# Index: [MSFT, MSFT, MSFT, MSFT, MSFT]

# %% [markdown]
# # New Section
